# %% [markdown]
# 1.statistics is a mathematical science which includes collecting , organising analyzing  the data such a way that a meaning conclusion can be drawn form it,
# statistics is used for understanding the pattern of the data.
# 2. the two types of statistics are Descriptive statistics and infrenncial statistics .
# 3.Descriptive statistics is about to summarize the whole data .
# 4. infresnical statistics includes sampling the data , and analyize the sample and inference it with the population .
# 5. sampling is to take some sample data from population
# 6.the sampling methods are Simple random sampling , stratified sampling , cluster sampling , systematic sampling .
# 7.in random sampling every member os the population has an equal chance to get selected in sample where in non random sampling there is difference .
# 8.Qualitative data are categorical data like blood group , gender etc, where as quantative data are numerical data like age ,height etc .
# 9.in statstics we have to deal with mainly Ordinal , nomial , interval ,ratio data .
# 10.in nominal data there is no order , where as ordinal data there is an order , and ration and interval data is numerical data having order , but in interval data may not have zero starting point , but in ratio data should have zero starting point .
# 11.in measure of central tendency we summrize the data by seeing the central element of the data , it includes mean ,median ,mode .
# 12.mean is calculated by sum of all the numbers divide by total number of element where as median is the middle value of the dataset after  it is sorted ,
# mode is max repetative element in the data set or whose freq is high .
# 13.in measure of central tendency we summrize the data by seeing the central element of the data , it includes mean ,median ,mode.
# 14.variance says how much the data sprayed , it is ratio of square of deference of every element of the data set from it mean to number of element in the data set .
# 15.standard deviation is the square root of variance , by it we can determine the dispersion of the data set
# 16. range is the differnce of max and min value of a data set .
# 17. in variance the dimension are squared but in standard deviation the dimension is same as the data set .
# 18. skewness is the measure of symmetricity of a data set .
# 19.if in any data set mean>median >mode it means it is right skewed , and if mode >median >mean it meand it is left skewed .
# 20.Kurtosis is a statistical measure which says of peakedness or flatness of the data .
# 21. covariance is used to detemine the relation between two dataset whether it is Direct relation or indirect  relation  .
# 22. correlation measure the relation ship between two data set whether it it positive correlated or negetive . it also says the measure of correlation .
# 23. covarianve has dimension but correaltion doest have any diemnsion , covariance can have any value but correlation vairies from -1 to +1 , covariance cant be compared but convariance can be comapred .
# 24. Statistics is widely used in real life. In healthcare, it helps in analyzing treatment effectiveness. Businesses use it to understand customers and predict sales. In finance, it’s key for risk analysis and forecasting. Engineers apply it for quality control and product reliability. Governments use statistics for census, planning, and policymaking.

# %%
# 1.How do you calculate the mean, median, and mode of a dataset?
import numpy as np
from scipy import stats
data=[4,6,7,9,4,32,23];
print(np.mean(data));
print(np.median(data));
print(stats.mode(data))
# Out:
# 12.142857142857142
# 7.0
# ModeResult(mode=np.int64(4), count=np.int64(2))

# %%
# 2.Write a Python program to compute the variance and standard deviation of a dataset.
import numpy as np
data=[4,6,7,9,4,32,23];
print(np.std(data))
print(np.var(data))
# Out:
# 10.133798771981828
# 102.6938775510204

# %% [markdown]
# # 3.Create a dataset and classify it into nominal, ordinal, interval, and ratio types
# --> Nominal means no order in data and it is a categorical data
# like gender , blood group etc
# -->ordinal means in data set there is an certian order like ranks
# grades.
# -->interval is for numerical data and deference can be measured like marks etc
# -->ratio data also for numerical data but there must be zero starting point like height weight etc.

# %%
# 5.Write a Python function to calculate the range of a dataset
data =[3,4,5,61,34,56]
rang_data=(max(data)-min(data))
print(rang_data)
# Out:
# 58

# %%
# 7. Calculate skewness and kurtosis of a dataset using Python libraries.
from scipy.stats import skew
from scipy.stats import kurtosis
data =[3,4,5,61,34,56];
skewness=skew(data)
print(skewness)
kur=kurtosis(data);
print(kur);
# Out:
# 0.28591824299786256
# -1.6947187801499202

# %%
#  9. Write a Python script to calculate covariance between two datasets.
import seaborn as sns
df=sns.load_dataset('taxis')
data=df.head()
covv=data.cov(numeric_only=True)
print(covv)
# Out:
#             passengers  distance      fare       tip  tolls      total
# passengers       0.800  -0.28200  -1.05000  -0.62600    0.0   -1.97600
# distance        -0.282   7.97893  25.39575   6.09249    0.0   31.14774
# fare            -1.050  25.39575  81.05000  19.54100    0.0   99.64100
# tip             -0.626   6.09249  19.54100   5.39127    0.0   24.79577
# tolls            0.000   0.00000   0.00000   0.00000    0.0    0.00000
# total           -1.976  31.14774  99.64100  24.79577    0.0  123.52527

# %%
# 10.Write a Python script to calculate the correlation coefficient between two datasets
import seaborn as sns
df=sns.load_dataset('taxis')
data=df.head()
corrr=data.corr(numeric_only=True)
print(corrr)
# Out:
#             passengers  distance      fare       tip  tolls     total
# passengers    1.000000 -0.111617 -0.130397 -0.301428    NaN -0.198776
# distance     -0.111617  1.000000  0.998647  0.928917    NaN  0.992148
# fare         -0.130397  0.998647  1.000000  0.934813    NaN  0.995826
# tip          -0.301428  0.928917  0.934813  1.000000    NaN  0.960847
# tolls              NaN       NaN       NaN       NaN    NaN       NaN
# total        -0.198776  0.992148  0.995826  0.960847    NaN  1.000000

# %%
# 16.Plot a boxplot to understand the spread and identify outliers
import seaborn as sns
data=[1,2,3,4,5,45,65.100];
box=sns.boxplot(data);

# %%
# 17.Calculate the interquartile range (IQR) of a dataset.
import numpy as np
data=[4,5,6,4,8,9,5,1,2,5,4,455,66],
per_data=np.percentile(data,[0,25,50,75,100])
IQR=per_data[3]-per_data[1]
print(IQR)
# Out:
# 4.0

# %%
 # 18.Write a Python program to visualize covariance using a heatmap
import seaborn as sns
df=sns.load_dataset('taxis')
data=df.head()
covv=data.cov(numeric_only=True)
print(sns.heatmap(covv,annot=True))
# Out:
# Axes(0.125,0.11;0.62x0.77)

# %%
# 22. Generate a dataset and implement both variance and standard deviation computations
import numpy as np
np.random.seed(42)
data=np.random.randint(1,40,15)
print(np.var(data))
print(np.std(data))
# Out:
# 112.50666666666666
# 10.60691598282303

# %%
# 6.Create a dataset and plot its histogram to visualize skewness
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew
np.random.seed(34)
data=np.random.exponential(scale=2.0,size=1000);
plt.figure(figsize=(8,10));
sns.histplot(data,bins=30,kde=True,color='yellow');
plt.title('Skewness');
plt.xlabel('value');
plt.ylabel('Frequency');
plt.grid(True)
plt.show();
print(skew(data))
# Out:
# 2.116169035339675

# %%
#  8.Generate a dataset and demonstrate positive and negative skewness
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew
np.random.seed(45)
right_skewd=np.random.exponential(scale=2.0,size=1000)
left_skewd= -right_skewd+max(right_skewd)+1;
plt.figure(figsize=(8,10));
sns.histplot(right_skewd,bins=30,kde=True,color='red');
plt.title("Right Skewed Data");
plt.xlabel("Value");
plt.ylabel("Frequency")
plt.grid(True);
plt.show();
sns.histplot(left_skewd,bins=30,kde=True,color='Skyblue');
plt.title("Left Skewed Data");
plt.xlabel("Value");
plt.ylabel("Frequency")
plt.grid(True);
plt.show();
print("the value of right Skewness: ",skew(right_skewd));
print("the value of left Skewness: ",skew(left_skewd));
# Out:
# the value of right Skewness:  1.8982238517566612
# the value of left Skewness:  -1.8982238517566612

# %%
#  11.Create a scatter plot to visualize the relationship between two variables.
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data1=[4,5,6,99,7,9,5,41,5,6,4,2,6,5,4,11,5,5,44,5,66,54,41,11,4,44,4];
data2=[4,6,9,8,7,1,2,3,6,55,6,9,5,45,6,5,5,9,6,1,1,5,6,6,5,5,5];
plt.figure(figsize=(8,10))
sns.scatterplot(x=data1,y=data2,color="red")
plt.title("Scatter Plot of data1 vs data2")
plt.xlabel("data1")
plt.ylabel("data2")
plt.grid(True)
plt.show()

# %%
#  23.Visualize skewness and kurtosis using Python libraries like matplotlib or seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew , kurtosis
np.random.seed(42);
data=np.random.randint(1,90,100);
data1=skew(data);
data2=kurtosis(data);
plt.figure(figsize=(8,10));
sns.histplot(data,bins=15,color="red",kde=True);
plt.title(f"Kurtosis: {data2:.2f}, Skewness: {data1:.2f}")
plt.xlabel("Data");
plt.ylabel("Frequancy");
plt.grid(True);
plt.show()

# %%
#  24.Implement the Pearson and Spearman correlation coefficients for a dataset
import numpy as np
from scipy.stats import pearsonr, spearmanr
np.random.seed(34);
data1=np.random.randint(1,50,100);
data2=np.random.randint(1,20,100);
print(pearsonr(data1,data2))
print(spearmanr(data1,data2))
# Out:
# PearsonRResult(statistic=np.float64(-0.10370897784287099), pvalue=np.float64(0.30450385169771055))
# SignificanceResult(statistic=np.float64(-0.1332880916709063), pvalue=np.float64(0.18615797233261833))

# %%
#  21. Use seaborn to create a correlation matrix for a dataset
import seaborn as sns
df=sns.load_dataset('taxis')
data=df.head()
covv=data.cov(numeric_only=True)
print(sns.heatmap(covv,annot=True))
# Out:
# Axes(0.125,0.11;0.62x0.77)

# %%
# 18.Implement Z-score normalization and explain its significance
import numpy as np
from scipy.stats import zscore
np.random.seed(43);
data=np.random.randint(1,45,5);
print(zscore(data))
# Out:
# [-0.93663133 -1.42959519  1.15846507  0.54226024  0.66550121]

# %%
# 19.Compare two datasets using their standard deviations
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(45);
data1=np.random.randint(1,20,5)
data2=np.random.randint(1,30,5)
std1=np.std(data1)
std2=np.std(data2);
plt.figure(figsize=(8,10));
sns.histplot(data1,bins=20,kde=True,color="red");
sns.histplot(data2,bins=20,kde=True,color="red");
plt.title(f"Standard1:{std1:.2f} , standard2: {std2:.2f}")
plt.xlabel("value")
plt.ylabel("frequency")
plt.grid(True)
plt.show()
